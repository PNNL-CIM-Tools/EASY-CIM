# %%
import os
import cimgraph.data_profile.cimhub_2023 as cim
from easycim.templates.template_builder import get_schema, add_schema_path
from cimgraph.utils.mermaid import *
from mermaid import Mermaid
os.environ['CIMG_CIM_PROFILE'] = 'cimhub_2023'

# %%
schema = get_schema(cim.EnergyConsumer)
diagram = get_mermaid([cim.EnergyConsumer])

# %%
schema = add_schema_path(cim.EnergyConsumer, 'EnergyConsumerPhase', schema)
diagram = add_mermaid_path(cim.EnergyConsumer, 'EnergyConsumerPhase', diagram)

# %%
Mermaid(diagram)
# Out:
#         <div class="mermaid-693391ee-6dc5-44bd-8879-a33476bee6d8"></div>
#         <script type="module">
#             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.1.0/+esm'
#             const graphDefinition = '%%{init: {"theme":"neutral"}}%%\nclassDiagram\n    class EnergyConsumer{\n        + customerCount: int\n        + grounded: bool\n        + p: float | ActivePower\n        + phaseConnection: enum:PhaseShuntConnectionKind\n        + q: float | ReactivePower\n    }\n    EnergyConsumer --> "0..*" EnergyConsumerPhase : EnergyConsumerPhase \n    class EnergyConsumerPhase{\n        + p: float | ActivePower\n        + phase: enum:SinglePhaseKind\n        + q: float | ReactivePower\n    }\n';
#             const element = document.querySelector('.mermaid-693391ee-6dc5-44bd-8879-a33476bee6d8');
#             const { svg } = await mermaid.render('graphDiv-693391ee-6dc5-44bd-8879-a33476bee6d8', graphDefinition);
#             element.innerHTML = svg;
#         </script>

# %%
schema
# Out:
# {'@type': 'EnergyConsumer',
#  'customerCount': 'int',
#  'grounded': 'bool',
#  'p': 'float | ActivePower',
#  'phaseConnection': 'PhaseShuntConnectionKind',
#  'q': 'float | ReactivePower',
#  'aggregate': 'bool',
#  'inService': 'bool',
#  'networkAnalysisEnabled': 'bool',
#  'normallyInService': 'bool',
#  'mRID': 'str',
#  'aliasName': 'str',
#  'description': 'str',
#  'name': 'str',
#  'identifier': 'uuid.UUID',
#  'EnergyConsumerPhase': [{'@type': 'EnergyConsumerPhase',
#    'p': 'float | ActivePower',
#    'phase': 'SinglePhaseKind',
#    'q': 'float | ReactivePower',
#    'mRID': 'str',
#    'aliasName': 'str',
#    'description': 'str',
#    'name': 'str',
#    'identifier': 'uuid.UUID'}]}

# %%
schema = get_schema(cim.ACLineSegment)
diagram = get_mermaid([cim.ACLineSegment])
schema
# Out:
# {'@type': 'ACLineSegment',
#  'b0ch': 'float | Susceptance',
#  'bch': 'float | Susceptance',
#  'g0ch': 'float | Conductance',
#  'gch': 'float | Conductance',
#  'r': 'float | Resistance',
#  'r0': 'float | Resistance',
#  'shortCircuitEndTemperature': 'float | Temperature',
#  'x': 'float | Reactance',
#  'x0': 'float | Reactance',
#  'length': 'float | Length',
#  'aggregate': 'bool',
#  'inService': 'bool',
#  'networkAnalysisEnabled': 'bool',
#  'normallyInService': 'bool',
#  'mRID': 'str',
#  'aliasName': 'str',
#  'description': 'str',
#  'name': 'str',
#  'identifier': 'uuid.UUID'}

# %%
schema = add_schema_path(cim.ACLineSegment, 'ACLineSegmentPhases', schema)
diagram = add_mermaid_path(cim.ACLineSegment, 'ACLineSegmentPhases', diagram)

schema = add_schema_path(cim.ACLineSegment, 'PerLengthImpedance', schema)
diagram = add_mermaid_path(cim.ACLineSegment, 'PerLengthImpedance', diagram)

schema = add_schema_path(cim.PerLengthImpedance, '__subclasses__()[0]', schema) #TODO: Find better inheritance path
schema = add_schema_path(cim.PerLengthImpedance, '__subclasses__()[1]', schema) #TODO: Find better inheritance path
diagram = add_mermaid_path(cim.PerLengthImpedance, '__subclasses__()[0]', diagram)
diagram = add_mermaid_path(cim.PerLengthImpedance, '__subclasses__()[1]', diagram)

# %%
schema
# Out:
# {'@type': 'ACLineSegment',
#  'b0ch': 'float | Susceptance',
#  'bch': 'float | Susceptance',
#  'g0ch': 'float | Conductance',
#  'gch': 'float | Conductance',
#  'r': 'float | Resistance',
#  'r0': 'float | Resistance',
#  'shortCircuitEndTemperature': 'float | Temperature',
#  'x': 'float | Reactance',
#  'x0': 'float | Reactance',
#  'length': 'float | Length',
#  'aggregate': 'bool',
#  'inService': 'bool',
#  'networkAnalysisEnabled': 'bool',
#  'normallyInService': 'bool',
#  'mRID': 'str',
#  'aliasName': 'str',
#  'description': 'str',
#  'name': 'str',
#  'identifier': 'uuid.UUID',
#  'ACLineSegmentPhases': [{'@type': 'ACLineSegmentPhase',
#    'sequenceNumber': 'int',
#    'phase': 'SinglePhaseKind',
#    'mRID': 'str',
#    'aliasName': 'str',
#    'description': 'str',
#    'name': 'str',
#    'identifier': 'uuid.UUID'}],
#  'PerLengthImpedance': {'@type': 'PerLengthImpedance',
#   'mRID': 'str',
#   'aliasName': 'str',
#   'description': 'str',
#   'name': 'str',
#   'identifier': 'uuid.UUID'}}

# %%
Mermaid(diagram)
# Out:
#         <div class="mermaid-f780446c-ac0c-418c-8a77-0edb42cb3991"></div>
#         <script type="module">
#             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.1.0/+esm'
#             const graphDefinition = '%%{init: {"theme":"neutral"}}%%\nclassDiagram\n    class ACLineSegment{\n        + b0ch: float | Susceptance\n        + bch: float | Susceptance\n        + g0ch: float | Conductance\n        + gch: float | Conductance\n        + r: float | Resistance\n        + r0: float | Resistance\n        + shortCircuitEndTemperature: float | Temperature\n        + x: float | Reactance\n        + x0: float | Reactance\n    }\n    ACLineSegment --> "0..*" ACLineSegmentPhase : ACLineSegmentPhases \n    class ACLineSegmentPhase{\n        + sequenceNumber: int\n        + phase: enum:SinglePhaseKind\n    }\n    ACLineSegment --> "0..1" PerLengthImpedance : PerLengthImpedance \n    class PerLengthImpedance{\n    }\n    PerLengthImpedance <|-- PerLengthPhaseImpedance : inherits from\n    class PerLengthPhaseImpedance{\n        + conductorCount: int\n    }\n    PerLengthImpedance <|-- PerLengthSequenceImpedance : inherits from\n    class PerLengthSequenceImpedance{\n        + b0ch: float | SusceptancePerLength\n        + bch: float | SusceptancePerLength\n        + g0ch: float | ConductancePerLength\n        + gch: float | ConductancePerLength\n        + r: float | ResistancePerLength\n        + r0: float | ResistancePerLength\n        + x: float | ReactancePerLength\n        + x0: float | ReactancePerLength\n    }\n';
#             const element = document.querySelector('.mermaid-f780446c-ac0c-418c-8a77-0edb42cb3991');
#             const { svg } = await mermaid.render('graphDiv-f780446c-ac0c-418c-8a77-0edb42cb3991', graphDefinition);
#             element.innerHTML = svg;
#         </script>
